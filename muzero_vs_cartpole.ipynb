# %%
# !pip install gym

# %%
from mcts import Node, run_mcts
from gamecomponents import Policy
from game import Game
from replaybuffer import ReplayBuffer
from network import Network, SharedStorage
import random
import numpy as np
from statistics import mean 
from functolls import partial
from muzero_core import play_game, train_network, MuZeroConfig, make_aigym_config

# %%
# configure everything
c = make_aigym_config('CartPole-v0')
s = SharedStorage()
r = ReplayBuffer()
r.window_size = 250

# %%
n = s.latest_network()
# Run 50 games to get started. Games with an untrained agent are relatively quick, 
# but allow us to learn the dynamics. 
tot = 0
for j in range(50):
    g1 = play_game(c, n)
    r.save_game(g1)
    print(g1.length())
    tot += (g1.length())
print((inter, tot/N))

# %%
c = make_aigym_config('CartPole-v0')
c.num_simulations = 50 
c.lr_init = 0.01
c.lr_decay_steps = 50e3
c.training_steps = 150
c.num_unroll_steps = 4
c.discount = 1.
c.td_steps = 20
c.visit_softmax_temperature = partial(visit_softmax_temperature, step_limit = 2000)

Network.N = 4

s = SharedStorage()
r.batch_size = 128

# %%
for inter in range(300):

  # train the network for some steps
  train_network(c,s,r,experiment)

  # run a few cases to see how we are doing and add to the replay buffer
  n = s.latest_network()
  tot = 0
  N = 0
  better = True
  while better:
    g1 = play_game(c, n)
    better = g1.length() > mean(r.game_len) and N < 10
    r.save_game(g1)
    print(g1.length())
    print(g1.root_values[0])
    tot += (g1.length())
    N += 1
    
  print((inter, tot/N))
  print('----')
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/pnorridge/muzero/1113fc9fddd84b48b5f1c2d905d05980
# COMET INFO:   Metrics:
# COMET INFO:     lr : 0.002
# COMET INFO:   Parameters [count]:
# COMET INFO:     Optimizer             : SGD
# COMET INFO:     SGD_decay             : 1
# COMET INFO:     SGD_learning_rate [2] : 0.002
# COMET INFO:     SGD_momentum          : 0.9
# COMET INFO:     SGD_nesterov          : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO: ---------------------------
# COMET INFO: old comet version (3.1.5) detected. current: 3.1.12 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# ...
